# %%
from utils import plot_mutual_information_plane_gas_ba

# %% [markdown]
# Constant slope

# %%
from data.c_slope_data import pi,qk,ski,N,r0,w0,z0

plot_mutual_information_plane_gas_ba(pi,qk,ski,N,r0,w0,z0,max_iter_gas=400,max_iter_ba=200,num_ib=20,num_betas=10)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:7: RuntimeWarning: divide by zero encountered in log
#   entropy=np.sum(np.where(p != 0, -p * np.log(p), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:7: RuntimeWarning: invalid value encountered in multiply
#   entropy=np.sum(np.where(p != 0, -p * np.log(p), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas.py:110: RuntimeWarning: divide by zero encountered in scalar divide
#   zeta=zeta-(G)/(np.sum(np.sum((ski @ (np.exp(R1 + zeta * (R2 - np.ones((M, 1))@(np.max(R2, axis=0).reshape(1,-1)))+f@np.ones((1,N))+np.ones((M,1))@(g.T))*(R2 - np.ones((M, 1))@(np.max(R2, axis=0).reshape(1,-1))))@np.diag(r.flatten()))*(np.log(ski@w@np.diag(r.flatten()))),axis=0),axis=0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas.py:111: RuntimeWarning: invalid value encountered in multiply
# ...

# %% [markdown]
# Bernoulli

# %%
from data.bernoulli_data import pi,qk,ski,N,r0,w0,z0
plot_mutual_information_plane_gas_ba(pi,qk,ski,N,r0,w0,z0,max_iter_gas=400,max_iter_ba=200,num_ib=30,num_betas=10)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas_2.py:69: RuntimeWarning: invalid value encountered in add
#   R = R1 + zeta * (R2 - np.ones((M, 1)) @ (np.max(R2,axis=0).reshape(1,-1)))  # M,N
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas_2.py:107: RuntimeWarning: invalid value encountered in add
#   G=np.sum(np.sum((ski@(np.exp(R1+zeta*(R2-np.ones((M,1))@(np.max(R2, axis=0).reshape(1,-1)))+f@np.ones((1,N))+np.ones((M,1))@(g.T)))@np.diag(r.flatten()))*np.log(ski@w@np.diag(r.flatten())),axis=0),axis=0)-c

# %% [markdown]
# Gaussian source

# %%
from data.gaussian_data import pi,qk,ski,N,r0,w0,z0


plot_mutual_information_plane_gas_ba(pi,qk,ski,N,r0,w0,z0,max_iter_gas=400,max_iter_ba=200,num_ib=30,num_betas=2)

# %% [markdown]
# Iris dataset

# %%
from data.iris_data import pi,qk,ski,N,r0,w0,z0

plot_mutual_information_plane_gas_ba(pi,qk,ski,N,r0,w0,z0,max_iter_gas=3000,max_iter_ba=200,num_ib=300,num_betas=10)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas_2.py:110: RuntimeWarning: divide by zero encountered in scalar divide
#   zeta=zeta-(G)/(np.sum(np.sum((ski @ (np.exp(R1 + zeta * (R2 - np.ones((M, 1))@(np.max(R2, axis=0).reshape(1,-1)))+f@np.ones((1,N))+np.ones((M,1))@(g.T))*(R2 - np.ones((M, 1))@(np.max(R2, axis=0).reshape(1,-1))))@np.diag(r.flatten()))*(np.log(ski@w@np.diag(r.flatten()))),axis=0),axis=0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas_2.py:111: RuntimeWarning: invalid value encountered in multiply
#   G=np.sum(np.sum((ski@(np.exp(R1+zeta*(R2-np.ones((M,1))@(np.max(R2, axis=0).reshape(1,-1)))+f@np.ones((1,N))+np.ones((M,1))@(g.T)))@np.diag(r.flatten()))*np.log(ski@w@np.diag(r.flatten())),axis=0),axis=0)-c
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\ib_algorithms\gas_2.py:86: RuntimeWarning: invalid value encountered in matmul
# ...

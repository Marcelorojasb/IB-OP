# %%
import numpy as np
from ib_algorithms.blahut_arimoto import ba_algorithm, calculate_py_t, plot_mutual_information_plane_ba
from itmetrics import mutual_information
import matplotlib.pyplot as plt
from data.irisdata import empirical_dist_iris

# %% [markdown]
# Se tiene py,px y py|x
# Se inicia p0t o p0t|x

# %%
plot_mutual_information_plane_ba(py_x,px,py,dim_N=2)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: invalid value encountered in divide
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: divide by zero encountered in divide
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:7: RuntimeWarning: divide by zero encountered in log
#   entropy=np.sum(np.where(p != 0, -p * np.log(p), 0))
# ...

# %% [markdown]
# Iris dataset

# %%
p_yx,py_x,px,py=empirical_dist_iris()

# %%
mutual_information(p_yx,py,px)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:7: RuntimeWarning: divide by zero encountered in log
#   entropy=np.sum(np.where(p != 0, -p * np.log(p), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:7: RuntimeWarning: invalid value encountered in multiply
#   entropy=np.sum(np.where(p != 0, -p * np.log(p), 0))
# 0.6600317525077066

# %%
plot_mutual_information_plane_ba(py_x,px,py,dim_N=4,num_betas=20,max_iter=200)
# Out:
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: divide by zero encountered in divide
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: invalid value encountered in divide
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# c:\Users\augus\Desktop\Teoria de la información\Proyecto\BA\itmetrics.py:32: RuntimeWarning: overflow encountered in divide
#   return np.sum(np.where(p != 0, p * np.log(p / q), 0))
# ...
